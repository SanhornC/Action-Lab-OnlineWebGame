# %% [markdown]
# # Zhifeng's Card Data Cleaning Notebook
#
# date: y2025m01d05
#
# ---

# %%
lines = open("cards_v0.csv", 'r').readlines()

# %%
def transform_line(original_line: str):
  ans_line = ""
  comma_count = 0
  for c in original_line:
    if c == ',':
      comma_count += 1
  curr_comma_count = 0
  for c in original_line:
    if c == ',':
      if curr_comma_count == 0 or curr_comma_count >= comma_count - 4:
        ans_line += ';'
      else:
        ans_line += ','
      curr_comma_count += 1
    else:
      ans_line += c
  return ans_line

# %%
lines
# Out:
# ['card_id, description, name, keyword1, keyword2, keyword3\n',
#  "1, 'A long-term partner with AAA,the company ME is the largest medicine distributor for influenza in Asia. ', 'S1T1C16', 'ME', 'Asia', 'Influenza'\n",
#  "2, 'Suppose AAA tries to expand its business sector for influenza treatment in Asia. In that case, the largest medicine distributor in Asia, ME, will be a candidate with potential.', 'S1T1C17', 'ME', 'expansion', 'AAA'\n",
#  "3, 'ME had stable growth in their sales revenue of 12%. Last year, the revenue was $450 million.', 'S1T1C1', 'ME', 'growth', 'revenue'\n",
#  "4, 'AAA\\'s board members maintained a good relationship with ME\\'s CEO. They had several public and private meetings during the last five years.', 'S1T1C18', 'ME', 'AAA', 'relationship'\n",
#  '5, \'The company pleaded guilty to the false promotion of prescription drug "Z" (which is related to influenza) in 2010, including kickbacks to doctors and pharmacists. All fines were paid.\', \'S1T1C25\', \'ME\', \'guilty\', \'false promotion\'\n',
#  "6, 'ME has a good relationship with Asian governments and several advocacy groups. But whether the relationship would be preserved after the acquisition is unknown.', 'S1T1C38', 'ME', 'relationship', 'Asian governments'\n",
#  "7, 'Some board members for ME have a strong connection with several Asian governments and advocacy groups. The relationship is beneficial but not easily maintained.', 'S1T1C26', 'ME', 'Asian governments', 'connection'\n",
#  "8, 'To maintain the advantage in bargaining with governments, the company should maintain $500 million in expenditures for lobbying to support the related advocacy groups and NGOs.', 'S1T1C2', 'ME', 'lobbying', 'expenditures'\n",
#  "9, 'The company was the first Western pharmaceutical company to set up a pharmaceutical factory in China in 1975.', 'S1T1C39', 'NJ', 'pharmaceutical factory', 'china 1975'\n",
#  "10, 'The company announced the result of a phase 3 study on a new vaccine for influenza. Clinical benefits continued to be observed across all the subgroups, and no safety signals were observed in longer follow-ups.', 'S1T1C19', 'NJ', 'safety', 'vaccine'\n",
#  "11, 'The company is developing a new generation vaccine for influenza. According to previous studies, the vaccine\\'s effectiveness could reach 70% with a 35% increase.', 'S1T1C3', 'NJ', 'vaccine', 'effectiveness'\n",
#  "12, 'NJ\\'s headquarter in California, US, was founded in 1995 by three prominent scientists. The main business is contract development and research.', 'S1T1C27', 'NJ', 'headquarter', 'business'\n",
#  "13, 'NJ owns research centers in East Asia and partnered with top universities. The research centers own patents for drugs in several diseases related to influenza. These patents are valued at over $500 million.', 'S1T1C4', 'NJ', 'patent', 'influenza'\n",
#  "14, 'NJ has a partnership with several research institutions in East Asia and Europe. They shared advanced techniques in pharmaceutical industries, such as artificial protein synthesis.', 'S1T1C28', 'NJ', 'partnership', 'research'\n",
#  "15, 'NJ partners with local manufacturers and owns several factories that mainly produce over-the-counter drugs. The relationship is believed to generate over $100 million in benefits.', 'S1T1C5', 'NJ', 'partnerships', 'factories'\n",
#  "16, 'NJ applied for 300 patents last year, and most of them were granted. It is the top twenty company for patent applications worldwide.', 'S1T1C29', 'NJ', 'top', 'patent'\n",
#  "17, 'NJ owns over ten thousand pharmaceutical patents. They devote lots of resources to developing new methods. Last year, about 300 patents were granted.', 'S1T1C30', 'NJ', 'patent', 'resources'\n",
#  "18, 'The research and development expense is continually growing. It is expected that an additional $300 million would be required in the following years for the ongoing projects.', 'S1T1C6', 'NJ', 'grow', 'research'\n",
#  '19, \'The company just started a partnership with a famous pharma, "ZA," and announced a project on drug development. It is expected that the cost of interference would be about $500 million.\', \'S1T1C7\', \'PI\', \'partnership\', \'pharma\'\n',
#  '20, \'If the partnership with famous pharma "ZA" can keep going after the acquisition, the total payoff for the future is expected to be $400 million.\', \'S1T1C8\', \'PI\', \'ZA\', \'acquision\'\n',
#  "21, 'The partnership built by ZA is believed to go on after AAA requires ZA. These partnerships can benefit AAA for about a $400 million payoff.', 'S1T1C20', 'PI', 'AAA', 'Benefit'\n",
#  "22, 'The company had several charges filed against it with the National Labor Relations Board in the past ten years. The labor union and the board have had severe opposition since 2015.', 'S1T1C21', 'PI', 'labor union', 'charges'\n",
#  "23, 'The employees of PI threatened that they would call for a strike if their company was merged. The cost of employee compensation is expected to be over $50 million.', 'S1T1C9', 'PI', 'compensation', 'strike'\n",
#  "24, 'The company has a history of over 100 years. The company was founded in 1885 and is based in Germany. Since then, its main products and service have been consumer health and over-the-counter drug.', 'S1T1C31', 'PI', 'history', 'Germany'\n",
#  "25, 'Last year, 50% of the company\\'s revenues came from Europe, 5% came from each of China and Japan, and 45% came from other countries.', 'S1T1C32', 'PI', 'revenue', 'countries'\n",
#  "26, 'SA is based in California, US, and it was founded by several prominent scientists five years ago. The company is famous for its low-cost small molecule drugs.', 'S1T1C33', 'SA', 'California', 'low-cost'\n",
#  "27, 'Last year, the company raised about $500 million in series E and series F from the venture funds. The company\\'s valuation reached $1 billion this year.', 'S1T1C34', 'SA', 'funds', 'valuation'\n",
#  "28, 'SA raised $500 million from venture funds last year. The company attracted private investors from B and C venture rounds, which sent the market a strong signal for their promising future.', 'S1T1C35', 'SA', 'funds', 'promising'\n",
#  "29, 'The effectiveness of small molecule drugs for common diseases, including flu, is similar to traditional medicines. However, the cost of production could be cut down by 15% by SA.', 'S1T1C10', 'SA', 'effectiveness', 'cost'\n",
#  "30, 'SA is working on the next-generation vaccine for influenza. The project started two years ago and partnered with leading research institutions. The vaccine development is in the pre-clinical stage.', 'S1T1C22', 'SA', 'influenza', 'pre-clinic'\n",
#  "31, 'SA still gained no profit since it was founded. There is a additional long-term debt on the account is $300 million discovered recently. If acquired by AAA, the debt will be counted as the cost for acquisition.', 'S1T1C11', 'SA', 'debt', 'loss'\n",
#  "32, 'SA did not generate any profit from its core business yet. Recently, the consultants discovered that there is an additional $300 million in long-term debt for SA. If AAA acquired SA, the amount should be counted into its cost.', 'S1T1C12', 'SA', 'profit', 'consultants'\n",
#  "33, 'The next-generation vaccine is expected to generate $1 billion in benefits if it succeeds. The successful rate is believed to be over 60% at this stage.', 'S1T1C13', 'SA', 'benefits', 'successful rate'\n",
#  "34, 'A severe winter storm strikes Europe this winter. Several important factories in Europe were destroyed. The cost of recovery is about $300 million.', 'S1T1C14', 'Europe', 'factories', 'storm'\n",
#  "35, 'Personalized medicine is a new trend for pharmaceutical companies, and precision therapies are increasingly adopted. Many other companies have started investing in the development of personalized medicines.', 'S1T1C36', 'new trend', 'personalized med', 'precision therapies'\n",
#  "36, 'The market growth is limited due to the labor force shortage, especially the skilled laborers for research and development. It is expected that the expenditure on labor will increase by 20%', 'S1T1C23', 'labor force ', 'shortage', 'expenditure'\n",
#  "37, 'US FDA had a stricter approval process for vaccine or drug testing. The cost of development is expected to increase by $100 million.', 'S1T1C24', 'strict', 'vaccine', 'cost'\n",
#  "38, 'Though the financial status of SA is not clear, it is a company with potential. Many talented scientists joined their research team.', 'S1T1C41', 'SA', 'potential', 'scientists'\n",
#  "39, 'Acquiring NJ can bring not only patent benefits but also strengthen the economic scale of AAA.', 'S1T1C15', 'NJ', 'economic', 'aquire'\n",
#  "40, 'North America was the largest pharmaceuticals market in the world, accounting for $46 of the global sales. Asia is the second largest market, with about 26% of the sales.', 'S1T1C40', 'global', 'pharmaceuticals market', 'largest'\n",
#  "41, 'According to a recent report, the global pharmaceuticals market is expected to grow at an average rate of 2% yearly.', 'S1T1C37', 'market', 'yearly', 'rate'\n",
#  "42, 'X\\'s headquarter is in the silicon valley. The building is bought from the most extensive media company. It also spent more than USD 10 million to renew the facility.', 'S1T2C1', 'X', 'headquarter', 'silicon valley'\n",
#  "43, 'Due to the highly competitive market and increasing authorization fee for the content, it is suggested that AAA should invest in original content after the acquisition. The cost is expected to be over $5 billion.', 'S1T2C10', 'X', 'AAA', 'invest'\n",
#  "44, 'X insists that AAA should allocate $500 million to ensure the labor right of the employees from X. Also, the compensation for these employees should not be worse than before. The cost is expected to be $500 million.', 'S1T2C11', 'X', 'labor right', 'employee'\n",
#  "45, 'The CEO of Y founded an organic health food store in 1997, and the store went bankrupt in 2001. Its failure was the non-reducible cost of goods and storage, leading to unattractive prices.', 'S1T2C12', 'Y', 'CEO', 'bankrupt'\n",
#  "46, 'Y is planning to expand its business into Latin America. However, developing the storage system and the delivery system is challenging. They are trying to reassess their ability.', 'S1T2C13', 'Y', 'expand', 'challenge'\n",
#  "47, 'Y faced challenges in the storage and delivery systems when expending its service in Latin America recently. They are trying to reassess their ability.', 'S1T2C14', 'Y', 'expand', 'reassess'\n",
#  "48, 'Y is a fresh food delivery service platform including meat and vegetables. Customers can order fresh food via app or website, and the company will deliver it the next day.', 'S1T2C15', 'Y', 'food', 'delivery'\n",
#  "49, 'Y is based in the US, and it was founded in 2005. The company expanded to Canada in 2008. It partnered with local farms and the delivery service.', 'S1T2C16', 'Y', 'base', 'US'\n",
#  "50, 'Company Y has continuously grown by 15% in the past five years. It is expected that the company can generate over $60 billion in revenue in the future.', 'S1T2C17', 'Y', 'revenue', 'grow'\n",
#  "51, 'Y owns several warehousing in California, which might be non-essential. After the acquisition, AAA will plan to integrate the storage of their original warehouses. The disposal of real estate in California is expected to result in an additional $2.5 billion in benefits.', 'S1T2C18', 'Y', 'California', 'warehouse'\n",
#  "52, 'AAA will choose to disposal of Y\\'s warehouses in California after the acquisition because these warehouses will be redundant to AAA\\'s original warehouses. There will be an additional $2.5 billion in benefits after the disposal.', 'S1T2C19', 'Y', 'warehouse', 'reduntant'\n",
#  "53, 'X has over ten thousand employees worldwide. The company emphasizes benefits to the employees. Compensation would be regular. Also, each year, the company holds several company trips to gel the teams.', 'S1T2C2', 'X', 'compensation', 'employees'\n",
#  "54, 'Y has lawsuits with a delivery company. The reason is that the delivery company regards a contract between them as proprietary, and Y cannot have other agreements with other delivery services. It is expected that Y will lose the lawsuit, and the compensation would be $10 million.', 'S1T2C20', 'Y', 'delivery company', 'lawsuits'\n",
#  "55, 'The consultant suggested that if AAA acquired Y and covered its service to all cities in the US, AAA must invest in refrigerated storage systems or partner with other companies. The cost would be $1 billion.', 'S1T2C21', 'Y', 'consultant', 'invest'\n",
#  "56, 'According to the evaluation reports, it is expected that AAA will spend about $5 billion to acquire Y successfully.', 'S1T2C22', 'Y', 'evaluation', 'acquisition'\n",
#  "57, 'Company Z is a cloud-based software company that was founded in 2005. The headquarter of the company is in Berlin, Germany. Z has international offices in San Francisco, Hon kong, and Singapore.', 'S1T2C23', 'Z', 'Berlin', 'software'\n",
#  "58, 'Company Z was founded in 2005 in Berlin, Germany. Z provides cloud computing services in Europe, Asia, and North America. It has recently expanded its offices to San Francisco, Hon Kong, and Singapore.', 'S1T2C24', 'Z', '2005', 'offices'\n",
#  "59, 'Z focuses on software as a service (SaaS) for customer relationship management. It provides solid and customizable web-based apps with numerous add-ons. Business users can quickly build, modify, or customize the services on the platform.', 'S1T2C25', 'Z', 'SaaS', 'CRM'\n",
#  "60, 'The company Z\\'s main business focused on cloud technologies. The platform provides companies with app building and data management services.', 'S1T2C26', 'Z', 'focus', 'technology'\n",
#  "61, 'Company Z provides ERP, data pipeline, and app server systems for corporate users. It is one of the promising cloud service companies.', 'S1T2C27', 'Z', 'ERP', 'promising'\n",
#  "62, 'The company had its initial public offering on the New York Stock Exchange and raised $1 billion in 2010. In 2015, the company issued $500 million in corporate bonds.', 'S1T2C28', 'Z', 'offering', 'Stock Exchange'\n",
#  "63, 'The demand for cloud computing has kept constantly growing these years. The expected payoff for the acquisition would be $50 billion for its core business.', 'S1T2C29', 'Z', 'demand', 'expected'\n",
#  "64, 'X is a US-based company founded in 2003. It was a DVD rental company at the beginning. After 2008, X transmitted into a streaming company providing video-on-demand service via the internet.', 'S1T2C3', 'X', 'streaming', 'DVD rental '\n",
#  "65, 'Z operates an add-ons development platform that also supports numerous programming languages and different data exchange types. It also hosts a marketplace for add-ons where corporate users can use the apps developed by professional developers', 'S1T2C30', 'Z', 'add-ons', 'marketplace'\n",
#  "66, 'Z takes a 10% commission for each payment on the add-ons platform.', 'S1T2C31', 'Z', 'commission', 'add on'\n",
#  "67, 'Z generates excellent profit from its add-ons platform. It can charge a 10% commission fee for each transaction on the platform.', 'S1T2C32', 'Z', 'commission', 'profit'\n",
#  "68, 'Company Z owns several patterns on cloud computing systems, especially the resource management and maintenance tools. After the acquisition, this will generate an additional $10 billion payoff for company AAA. ', 'S1T2C33', 'Z', 'patent', 'payoff'\n",
#  "69, 'In 2016, Z acquired a data visualization company. This helped Z successfully develop a better data analysis environment and generate over $1 billion in benefits for them.', 'S1T2C34', 'Z', 'visualization', 'successful'\n",
#  "70, 'Due to the Covid-19 pandemic, the transportation fees have increased by over 25% for all cargo worldwide.', 'S1T2C35', 'General', 'pandemic', 'transportation'\n",
#  "71, 'The transportation fee worldwide has increased by about 25% because of the out break of the Covid-19 pandemic.', 'S1T2C36', 'General', 'transportation', 'increase'\n",
#  "72, 'The US government encourages corporates to invest in clouds and robotics. It is expected that the policies will lead to an additional 10% payoff for US-based cloud computing or AI companies.', 'S1T2C37', 'General', 'clouds', 'robotics'\n",
#  "73, 'The tariff in Asia several countries is expected to rise from 10% to 30%. This is because of the trading conflict between the US and these countries', 'S1T2C38', 'General', 'rise', 'tariff'\n",
#  "74, 'It is expected that the company tax for Europe will rise in these years, and it will evitably affect the payoff for all Europe-based companies. The amount of influenced payoff is expected to be 15%.', 'S1T2C39', 'General', 'Europe', 'company tax'\n",
#  "75, 'X has been a DVD rental company since 2003. However, after 2008, X started its video streaming service. On-demand video service has become more and more popular in recent years.', 'S1T2C4', 'X', 'DVD rental', 'video-service'\n",
#  "76, 'The board of AAA\\'s directors hopes to expand the business into the video streaming business. Therefore, X would be the option that meets their wishes.', 'S1T2C40', 'X', 'expand', 'AAA'\n",
#  "77, 'Several market research suggested that cloud computing is growing at a fast pace. The current evaluation method might undervalue these companies.', 'S1T2C41', 'Z', 'market research', 'cloud computing'\n",
#  "78, 'During the covid pandemic, e-commerce proliferated. It had grown 50% of sales for the global market compared to the previous year.', 'S1T2C42', 'General', 'pandanmic', 'e-commerce'\n",
#  "79, 'X faced slow growth (1% to 0.5% yearly) in the DVD rental business since 2006 and started losing monthly customers for DVD rentals in 2008 (-15%). Due to the saturation of the DVD rental market and the fast growth of the internet content, X began a fast pace to transit into an online streaming company.', 'S1T2C5', 'X', 'slow growth', 'DVD rental'\n",
#  "80, 'Currently, X has over 20 million subscribers in the US and 15 million subscribers in Europe. The subscription growth rate has been about 10% in recent years.', 'S1T2C6', 'X', 'subscribers', 'growth'\n",
#  "81, 'X owns the patents of the recommender systems in contents. If AAA acquires X, the system can be integrated into the search engine of the original website. This is expected to generate accumulated $50 billion benefits to AAA.', 'S1T2C7', 'X', 'patents', 'recommender systems'\n",
#  "82, 'X owns patents for video user-based recommender systems. AAA can utilize the techniques on their search engine after acquiring X. The system will benefit AAA for about $50 billion.', 'S1T2C8', 'X', 'patents', 'search engines'\n",
#  "83, 'It is expected that the subscribers will continually grow for the next three years. The average growth rate is expected to be 8%.', 'S1T2C9', 'X', 'expect', 'subscriber'\n",
#  "84, 'Auro has had several experiences in holding national athlete or sports games in the past 30 years. Also, there are several mature athletes organizations to support the games. This will result in an additional 100 payoff.', 'S1T3C1', 'Auro', 'national', 'athlete'\n",
#  "85, 'Auro is one of the centers of the great agricultural area. There are several international agricultural companies based in the city. The companies backed the city government by sponsoring the game to increase their reputation. The support of the fund will generate 150 outcome.', 'S1T3C3', 'Auro', 'agriculture', 'center'\n",
#  "86, 'Auro is a well-known city in the agricultural zone. There are many headquarters of international farm companies in the city. These companies are willing to support the city government to hold the game and gain a reputaion. The support of the fund will generate 150 outcomes.', 'S1T3C4', 'Auro', 'agriculture', 'companies'\n",
#  "87, 'After the city government of Auro announced its seeking to host the game, there were protests everywhere in the city. The residents opposed the game because it would bring crowds, noise, and garbage pollution.', 'S1T3C7', 'Auro', 'protest', 'oppose'\n",
#  "88, 'There are protests every weekend at the city square to protest the game. The residents believed there would be crowds, noise, and garbage pollution when holding the game based on their experience.', 'S1T3C8', 'Auro', 'protest', 'square'\n",
#  "89, 'The transportation in Auro highly relies on private vehicles. Though there is a long-term plan for a new-built metro system, the project cannot fully support the participants and visitors for the game. It is expected that there will be some traffic problems when holding the tournament. The research suggested that a 50 payoff reduction may apply.', 'S1T3C10', 'Auro', 'transportation', 'problems'\n",
#  "90, 'Basa has a long history of culture and art. The cities often hold international exhibitions of fine art. However, many crimes such as violence and robbery happened in the past time of large campaigns. This would increase the risk and cost for safety and orders. (This results in a 200 payoff reduction.)', 'S1T3C12', 'Basa', 'history', 'crimes'\n",
#  "91, 'Basa is a historical city with culture and art. Almost every year, there are exhibitions of fine art. However, as a city with many tourists, there are several safety issues, such as violence and robbery. To maintain order, the city government should put effort and resources into the issue, which will lead to an additional cost of 200 payoffs.', 'S1T3C13', 'crimes', 'Basa', 'arts'\n",
#  "92, 'The city Basa welcomes tourists from all around the world. Last year, the city government raised funds from tourists for about 10 billion. Also, the city council had passed a 5 billion budget for holding the game. (This could generate 100 payoffs.)', 'S1T3C14', 'Basa', 'tourists', 'budget'\n",
#  "93, 'Basa is located in the middle of the continental. The train systems are well developed. Travelers can connect to other countries or main cities via train. Also, the international airport can be connected by train in 30 mins. The convenience could generate 150 payoffs.', 'S1T3C20', 'Basa', 'locate', 'convenience'\n",
#  "94, 'Cilia had limited experience in holding international sports games. It should generate additional spending to seek consultants and supporters. The condition will result in a 50 payoff reduction.', 'S1T3C22', 'Cilia', 'limited', 'experience'\n",
#  "95, 'Cilia is a new growing town that has limited experience in holding large international campaigns. They will need more resources to consult the experts and do research. This will result in an additional 50 payoff of the cost.', 'S1T3C23', 'Cilia', 'campaigns', 'limited'\n",
#  "96, 'The city Cilia is one of the famous villages for technological industries. Many international companies have branches in Cilia, including finance, technologies, and biology companies. Several companies showed interest in sponsoring the game. This could result in a 100 payoff.', 'S1T3C24', 'Cilia', 'technology', 'companies'\n",
#  "97, 'Cilia has a newly built metro system that includes two main lines. Travelers can travel from the airport to the city via the line in 30 mins. Also, there are several developing zones for establishing new sports fields among the metro lines. The convenience results in a 100 payoff.', 'S1T3C29', 'Cilia', 'convenience', 'metro systems'\n",
#  "98, 'Debu\\'s government had a total of $20 billion in short-term and long-term debt. It is believed that the city will go bankrupt in five years. It is because of the decline of the steel industry and the poorly planned financial support.', 'S1T3C31', 'Debu', 'debt', 'bankrupt'\n",
#  "99, 'Debu is a traditional city with heavy industries such as steel, boatbuilding, and petrochemical industries. The issue of air pollution is severe in the city. It is believed that a reduction of 100 payoffs for the pause of operation and athletes\\' health.', 'S1T3C34', 'Debu', 'air pollution', 'heavy industies'\n",
#  "100, 'Debu has one of the most extensive subway systems in urban and suburban areas. The connection between airports, tourist spots, and main events fields. It is believed that this could generate 200 payoffs for the game.', 'S1T3C36', 'Debu', 'extensive', 'subway'\n",
#  "101, 'Debu\\'s city government is almost bankrupt. They got a total of $20 billion in debt. The experts believed that the city would go bankrupt in five years because of less tax income from the declining steel industry.', 'S1T3C37', 'Debu', 'bankrupt', 'tax'\n",
#  "102, 'The team should consider their resource and potential to host a better game. The factors include: (1) funds and sponsors, (2) transportation, (3) game fields, (4) residents  attitude to the game, (5) experience in holding large campaign, etc.', 'S1T3C39', 'Rule', 'resource', 'factors'\n",
#  "103, 'According to the rules of host selection, we should exclude the city that residents oppose to the game, or the city with hard financial situation which cannot raise sufficient funds.', 'S1T3C40', 'Rule', 'selection', 'exclude'\n",
#  "104, 'The city with strong opposition from the citizen should not be considered to host the game. For example, we can expect a strong protest in the town for Auro to host the game. ', 'S1T3C42', 'Auro', 'Rule', 'protest'\n",
#  "105, 'Auro had never held an international game. Therefore, they had limited experience in holding global campaigns.', 'S1T3C2', 'Auro', 'experience', 'limited'\n",
#  "106, 'Auro\\'s city government plans to hold a fundraising campaign. The plans include sponsors by the citizens and tourists with limited souvenirs designed by well-known artists.', 'S1T3C5', 'Auro', 'fundraising', 'plan'\n",
#  "107, 'Basa is famous for its boat traveling. Travelers can take boats in the canals through the city and connect to popular tourist spots.', 'S1T3C18', 'Basa', 'boat traveling', 'connect'\n",
#  "108, 'The population of Cilia is relatively young. Over 70% of the residents are below 50. Also, a survey shows over 85% of the citizens enjoy physical activities and love sports competitions.', 'S1T3C28', 'Cilia', 'population', 'young'\n",
#  "109, 'The local congress and the residents in Debu believe that holding a tremendous physical game could bring glory back to the city. Both the government and people are very welcome to become the host of the game.', 'S1T3C35', 'Debu', 'residents', 'welcome'\n",
#  "110, 'The population of Auro has increased 50% in the last 20 years. It was elected as one of the most livable cities for retired people by the Liveability Survey. Auro is famous for its weather and public utilities.', 'S1T3C6', 'Auro', 'population', 'grow'\n",
#  "111, 'The nearest international airport to Auro is ABC Airport which is 35 miles away. The connection between the airport and the city mainly relies on commuting buses. Traveling from the airport to the city takes about one and a half hours.', 'S1T3C9', 'Auro', 'commute', 'airport'\n",
#  "112, 'Basa has a long history of culture and art. Since the 18th century, the cities have held an art exhibition and competition every two years. The campaign appeals to millions of travelers worldwide and generates more than millions of incomes nowadays.', 'S1T3C11', 'Basa', 'exhibition', 'competition'\n",
#  "113, 'Basa is famous for its long history, founded in the middle ages. Tourists often enjoyed its art, architecture, culture, and cuisine.', 'S1T3C15', 'Basa', 'famous', 'tourists'\n",
#  "114, 'The citizen of Basa has a well-known culture of hospitality and genuity. Most of the residents hold a positive attitude toward large campaigns. This might be because the city highly relies on the income from tourists.', 'S1T3C17', 'Basa', 'citizen', 'hospitality'\n",
#  "115, 'Cilia held an agricultral exposition last year. The exhibition emphasized the interaction between humans and environments involving new technologies for sustainable solutions. The exhibition appealed to more than 100 thousand visitors.', 'S1T3C21', 'Cilia', 'exhibition', 'ariculture'\n",
#  "116, 'Debu had several experiences in holding large and worldwide industrial exhibitions. The topics include new techniques, robotics, technology systems, and manufacturing applications. Each event could appeal to millions of visitors worldwide, including well-known cooperates.', 'S1T3C30', 'Debu', 'experience', 'exhibitions'\n",
#  "117, 'Debu also has perfect highway systems. Because of the declining population, traffic jams have been very rare in recent years.', 'S1T3C38', 'Debu', 'traffic', 'highway'\n",
#  "118, 'The weather in Basa is comfortable in summer, the time the game is holding. It seldom rains or has storms during that season.', 'S1T3C16', 'Basa', 'summer', 'weather'\n",
#  "119, 'Many travelers enjoy the boat tour at the canal of Basa. Travelers can take boats in the canals through the city and connect to famous tourist spots.', 'S1T3C19', 'Basa', 'travelers', 'boat'\n",
#  "120, 'Though Cilia is a young city, the utilities and businesses are well-formed. There are many shopping malls, amusement parks, bars, and clubs. Also, for about 50 mins travel, tourists can visit a great scenic area for camping and hiking.', 'S1T3C25', 'Cilia', 'young city', 'utilities'\n",
#  "121, 'In 1950, there was a catastrophic flood striking Debu. Over 1,000 people were injured, missing, or dead. This kind of flood is rare, but the city spent lots of resources to prevent another strategy after that.', 'S1T3C32', 'Debu', 'flood', 'rare'\n",
#  "122, 'There was a devastating flood to Debu in 1950. The disaster took away about 1,000 lives and resulted in lots of homeless people. After the flood, the city spent lots of resources on flood control and welfare for the homeless.', 'S1T3C33', 'Debu', 'flood', 'strategy'\n",
#  "123, 'Cilia emphasizes environmental protection and management. The city has strict policies on garbage disposal and classification. There will be fines for breaking the rules. Also, there are additional awards for green buildings.', 'S1T3C26', 'Cilia', 'environment', 'strict'\n",
#  "124, 'Cilia has stringent regulations on the garbage disposal. There are fines for misclassification or littering. They also spend resources on encouraging environmental protection, such as rewarding green buildings.', 'S1T3C27', 'Cilia', 'strict', 'regulation'\n",
#  "125, 'The most crucial factor for a city to hold the game is its tourist resources. We believe these cities can smoothly arrange the activities and deal with the issues that come from the crowds.', 'S1T3C41', 'Rule', 'crucial', 'tourist'\n",
#  "126, '[Victim] The collections include several out-of-print, high-valued records. These records might take over $2,000 in the secondhand market. Therefore, I think the guy might be someone familiar with this.', 'S2T1C4', 'Victim', 'high-valued records', 'secondhand market'\n",
#  "127, '[Victim] The collections were stored in a wooden box. The box was quite large. An empty box is weighed about 5 kilograms. It is possible to be lifted by one person, but the guy might be strong.', 'S2T1C5', 'Victim', 'strong', 'box'\n",
#  "128, '[Detective] There is a large wooden box for storing all collections. The box only weighed about 5 kilograms. It is possible that the collection be lifted by a strong person only.', 'S2T1C6', 'Detective', 'strong', 'box'\n",
#  "129, '[Victim] We were not at home yesterday. We took a trip to Chicago yesterday and stayed there for a night. We were back this morning. Then when I went upstairs to the room storing the collections, I found that the whole box of the collection was gone.', 'S2T1C8', 'Victim', 'Chicago', 'collection'\n",
#  "130, '[Neighbor] Suspect C often goes to the gyms, and we believe that he can easily lift the boxes as heavy as the description.', 'S2T1C12', 'Neighbor', 'Suspect C', 'gym'\n",
#  "131, '[Neighbor] Suspect C visited my house last night and left my place at 2 a.m. The time would take about 15 minutes from my site to the victim\\'s house.', 'S2T1C22', 'Neighbor', 'Suspect C', 'last night'\n",
#  "132, '[Detective] A phonograph record is weighted from about 120 grams to 200 grams. The size is from 10 to 15 inches in diameter. The records and the storage box are all gone.', 'S2T1C25', 'Detective', 'photgraph', 'size'\n",
#  "133, '[Detective] There is evidence that B is in debt. The guy is heavily addicted to computer games, and he spends lots of money on them. We believe that B needs additional funds to support the living cost.', 'S2T1C35', 'Detective', 'Suspect B', 'debt'\n",
#  "134, '[Victim] B often borrows or begs money from the neighbors. He spent most of his money on computer gaming and left nothing for his daily spending.', 'S2T1C36', 'Victim', 'Suspect B', 'money borrowing'\n",
#  "135, '[Detective] Several witnesses suggested that suspect B was at the fast-food restaurant the whole night on the day of the incident.', 'S2T1C37', 'Detective', 'Suspect B', 'restaurant'\n",
#  "136, '[Detective] Suspect A might have had financial problems recently. He owed a huge amount of debt due to the failure of an investment.', 'S2T1C40', 'Detective', 'Suspect A', 'debt'\n",
#  "137, '[Detective] The records were found in the second-hand store about 10 miles from the town. As per the report from the store owner, the guy who sold the collection understood how valuable the records were.', 'S2T1C41', 'Detective', 'records', 'found'\n",
#  "138, '[Neighbor] I saw suspect A hanging and sneaking around. He carried a backpack and looked around, seeming to prevent any witnesses. Also, he left a lever when he opened his trunk.', 'S2T1C43', 'Neighbor', 'Suspect A', 'sneaking'\n",
#  "139, '[Neighbor] Suspect A owns a car in color of red, and he also owns a motorcycle in the color red. His neighbor said that they did not see the car that night.', 'S2T1C10', 'Neighbor', 'Suspect A', 'car'\n",
#  "140, '[Neighbor] Suspect A owns a red car and a red motorcycle. The car wasn\\'t in the garage last night.', 'S2T1C11', 'Neighbor', 'Suspect A', 'garage'\n",
#  "141, '[Neighbor] Suspect B is a friend of the victim. He often visited his house. He might be familiar with the victims\\' items\\' locations.', 'S2T1C19', 'Neighbor', 'victim', 'Suspect B'\n",
#  "142, '[Neighbor] There were dogs barking last niight around 1 a.m. It sounded like the victim\\'s pet. I suspected it was the time the crime happened.', 'S2T1C20', 'Neighbor', 'dogs', 'barking'\n",
#  "143, '[Neighbor] The victim has a dog that did not travel with the family last night. The dog was barking indignantly around 1 a.m. I believe it is the time that the crime happened.', 'S2T1C21', 'Neighbor', 'bark', '1am'\n",
#  "144, '[Neighbor] C owns a car in the color of red, and he also owns a motorcycle in the color of blue. His neighbor said that they did not see the car in the garage that night.', 'S2T1C24', 'Neighbor', 'Suspect C', 'car'\n",
#  "145, '[Detective] There were traces in the front yard of the victim\\'s house. However, there are no signs that the criminal had moved any other items.', 'S2T1C26', 'Detective', 'traces', 'move'\n",
#  "146, '[Victim] When we were back home, we saw several footprints on the grassland of our yard. However, the door is still locked, and nothing was moved in the front yard.', 'S2T1C27', 'Victim', 'footprints', 'locked'\n",
#  "147, '[Detective] The guy might break into the house through the front door because we found some tools left around there.', 'S2T1C28', 'Detective', 'front door', 'break'\n",
#  "148, '[Detective] Suspect A worked in a music records store at a young age. He might be familiar with the value of records.', 'S2T1C31', 'Detective', 'Suspect A', 'work'\n",
#  "149, '[Detective] Suspect A works out three times a week. We believe that A can lift the box of collections quite easily.', 'S2T1C32', 'Detective', 'Suspect A', 'lift'\n",
#  "150, '[Detective] We believe that C does not have any financial problems. He has almost a $5 million deposit in the bank.', 'S2T1C38', 'financial', 'Suspect C', 'Detective'\n",
#  "151, '[Neighbor] C did not face any financial issues, as we know. Rumor has it that he owns over $5 million cash in his bank account.', 'S2T1C39', 'Neighbor', 'Suspect C', 'rumor'\n",
#  "152, '[Victim] It is my favorite music records collections, and most of them are phonograph records. There are about 500 pieces included in the collection.', 'S2T1C1', 'Victim', 'records', 'collections'\n",
#  "153, '[Neighbor] Yesterday, I saw A wearing a black T-shirt with blue jeans. Also, he keeps wandering near the victim\\'s house in the afternoon.', 'S2T1C9', 'Neighbor', 'Suspect A', 'wearing'\n",
#  "154, '[Detective] The suspect C owned a record player. It seems that the guy is also a collector of phonograph records.', 'S2T1C33', 'Detective', 'Suspect C', 'record player'\n",
#  "155, '[Neighbor] The last time I visited suspect C\\'s house, I saw a delicate record player. Suspect C is also a lover of phonograph records.', 'S2T1C34', 'Neighbor', 'Suspect C', 'record player'\n",
#  "156, '[Victim] The collections were stored on the second floor, and it was next to the record player. It can be reached quite easily. Also, the room is never locked.', 'S2T1C7', 'Victim', 'collections', 'second floor'\n",
#  "157, '[Neighbor] A is a polite and friendly person. He always smiles at me when he is jogging in the morning.', 'S2T1C13', 'Neighbor', 'Suspect A', 'polite'\n",
#  '158, \'[Neighbor] I knew the suspect "B." The guy lives in the neighborhood. There are always some bad rumors that the guy had violent records at a young age. Also, the guy seems to be addicted to alcohol.\', \'S2T1C14\', \'Neighbor\', \'Suspect B\', \'bad rumors\'\n',
#  "159, '[Neighbor] Suspect B has a terrible reputation. Rumor has it that he committed a violence crime at a young age. What\\'s more, he is addicted to alcohol.', 'S2T1C15', 'Neighbor', 'Suspect B', 'alcohol'\n",
#  "160, '[Neighbor] C often quarrels with the victim. It is because the victim often played music at high volume, and C thought it was pretty bothering.', 'S2T1C23', 'Neighbor', 'Suspect C', 'victim'\n",
#  "161, '[Detective] A security camera had an image of a car stopping in front of the victim\\'s house. However, it did not capture any person or the car plate. The car was in the color red.', 'S2T1C29', 'Detective', 'car', 'red'\n",
#  "162, '[Victim] The security camera in front of the front door captured a car stopping by my place for a very long time last night. However, neither the person nor the car plate was captured, while it was a red car.', 'S2T1C30', 'Victim', 'last night', 'red car'\n",
#  "163, '[Victim] The collections of phonograph records include various types of genres, including classical, jazz, and pop music at the time. The produced years were from 1920 to nowadays.', 'S2T1C2', 'Victim', 'genre', 'collections'\n",
#  "164, '[Detective] The collection includes lots of precious phonograph records. Various genres are included, such as classical, jazz, and pop music at the time. The collection was from 1920 to nowadays.', 'S2T1C3', 'Detective', 'precious', 'records'\n",
#  "165, '[Neighbor] Suspect B often wear a red T-shirt in the neighborhood. Yesterday, he also wear a red T-shirt and jeans.', 'S2T1C16', 'Neighbor', 'Suspect B', 'wear'\n",
#  "166, '[Neighbor] Suspect B is always cold to the neighbors. We don\\'t like him very much because he never responds to the greeting.', 'S2T1C17', 'Neighbor', 'Suspect B', 'cold'\n",
#  "167, '[Neighbor] Suspect B is unwelcome to us because he looks vicious all the time. Not to mention that he never greets the neighbors.', 'S2T1C18', 'Neighbor', 'Suspect B', 'vicious'\n",
#  "168, '[Victim] I believe that B stole my collection. We argued about my collection last week, and B thought these records were tacky and not worth my time and money. I believe these are his words to lower my awareness.', 'S2T1C42', 'Victim', 'Suspect B', 'argue'\n",
#  "169, '[Detective] According to the account records, there should be $8,000 in the treasury. However, we found that there the money was gone. Also, we cannot find the key to the treasury. The case should be related to money, including money disputes or robbery.', 'S2T2C1', 'Detective', 'key', 'treasury'\n",
#  "170, '[Former Employee] The owner always brings a bunch of keys with him, and these keys include the key for the treasury. ', 'S2T2C4', 'Former Employee', 'owner', 'keys'\n",
#  "171, '[Former Employee] The owner\\'s key for the treasury was gone. Until now, no one found the key yet. We believed that the suspect use that key to open the treasury. After the suspect stole the money, he/she throw it away.', 'S2T2C5', 'Former Employee', 'gone', 'key'\n",
#  "172, '[Prophet] The treasure was in the room of the owner, which is on the hotel\\'s second floor. Several people entered that room and the chamber yesterday. These people included the wife, the chief, and the counter.', 'S2T2C9', 'Prophet', 'room', 'treasury'\n",
#  "173, '[Prophet] A kind of cyanide poisoned the owner. The symptoms of cyanide poisoning include vomiting, low heart pressure, shortness of breath, etc. The murderer put the poison into the ower\\'s milk, and the owner drank it before he slept.', 'S2T2C10', 'Prophet', 'owner', 'poison'\n",
#  "174, '[Former Employee] The milk powder the owner used each night was placed in a private place near the kitchen. It was a secret place that only the owner himself, the wife, and the chef often visited there.', 'S2T2C23', 'Former Employee', 'milk powder', 'kitchen'\n",
#  "175, '[Former Employee] The milk which used by the owner daily is stored in the cabbin near the kitchen. Only few people passed the place including the owner himself, the chef, and the wife.', 'S2T2C24', 'Former Employee', 'milk', 'few people'\n",
#  "176, '[Prophet] The milk used by the owner daily is stored in the cabin near the kitchen. Only a few people passed the place, including the owner himself, the chef, and the owner\\'s wife.', 'S2T2C25', 'Prophet', 'milk', 'few people'\n",
#  "177, '[Former Employee] The owner\\'s wife manages most of the cash flows of the hotels. When there is a significant expense, we should first discuss it with her.', 'S2T2C37', 'Former Employee', 'wife', 'cash flow'\n",
#  "178, '[Detective] There are monitor records from the chemical store in the nearest town. A man who looked like a chef had visited the store in mask three times last week.', 'S2T2C43', 'Detective', 'chef', 'chemical store'\n",
#  "179, '[Detective] The owner seems to vomit, suffocate, and lie in the kitchen. He might drink or eat something before he died. Some poison may have killed him. However, we did not find any cup of drink remained in the kitchen. It could be washed away.', 'S2T2C2', 'Detective', 'owner', 'poison'\n",
#  "180, '[Detective] A bottle of milk powder was found in the trash can outside the kitchen. As we send it for the test, we found out there is cyanide in it.', 'S2T2C3', 'Detective', 'milk', 'cyanide'\n",
#  "181, '[Former Employee] The key, which belongs to the owner of the treasury, is still missing. The scene had been searched for several times, but nothing was found. The suspect might steal the key.', 'S2T2C6', 'Former Employee', 'key', 'missing'\n",
#  "182, '[Villager] Rumor has it that the hotel\\'s owner has a close relationship with another woman. The woman works in another city, and the owner visits her once a week. He could have an affair with her.', 'S2T2C12', 'owner', 'Villager', 'rumor'\n",
#  "183, '[Detective] The brother was laid out recently and broke up with his wife. His house in the city was expropriated by the bank for his debt. He had no places to go and came back to the village.', 'S2T2C14', 'Detective', 'brother', 'laid out'\n",
#  "184, '[Former Employee] The brother recently moved back from the town because he lost his job and broke up with his wife.', 'S2T2C15', 'Former Employee', 'brother', 'job'\n",
#  "185, '[Prophet] The brother plans to ask the owner to join the hotel operation. However, not until he told his brother the truth the tragedy had happened.', 'S2T2C17', 'Prophet', 'brother', 'join'\n",
#  "186, '[Detective] The chef has a habit of gambling. He is not in good luck recently and lost lots of money in the casino. According to the bank statement, he owes eight people 6 thousand dollars in total.', 'S2T2C22', 'Detective', 'chef', 'gamble'\n",
#  "187, '[Detective] There were fingerprints from the counter on the door of the second floor. Also, there are his fingerprints on the treasury.', 'S2T2C28', 'Detective', 'counter', 'fingerprints'\n",
#  "188, '[Former Employee] After the counter finishes the daily records, he usually puts the daily income in the treasury and report to the owner\\'s wife.', 'S2T2C29', 'Former Employee', 'counter', 'treasury'\n",
#  "189, '[Prophet] The counter opened the treasury daily to put daily income into it after he finished the records. He will also report the earnings to the owner\\'s wife.', 'S2T2C30', 'Prophet', 'counter', 'income'\n",
#  "190, '[Villager] I saw the owner\\'s wife shouting at the hotel\\'s owner last night. It seems they had a dispute on who should clean up the place after business. They have often argued about this since they married.', 'S2T2C41', 'Villager', 'wife', 'argue'\n",
#  "191, '[Detective] The brother does not work for the hotel. Actually, he graduated from college 10 years ago and now works as a waiter in a restaurant in other cities. The salary should be able to support his daily expense.', 'S2T2C13', 'Detective', 'brother', 'waiter'\n",
#  "192, '[Prophet] The owner\\'s wife slept alone in another room last night, and she did not know where her husband was. In the morning, when she woke up for morning exercise, she saw the owner was killed and lying in the hotel\\'s kitchen.', 'S2T2C34', 'Prophet', 'wife', 'last night'\n",
#  "193, '[Villager] The wife invests the real estate in the village and the town. However, the price has gone down in recent years, and she might suffer from some loss.', 'S2T2C36', 'Villager', 'wife', 'invest'\n",
#  "194, '[Villager] The wife is always kind to the neighbors, but we often hear the couple arguing their opinions on politics.', 'S2T2C40', 'Villager', 'wife', 'kind'\n",
#  "195, '[Detective] The owner had a habit of drinking a cup of milk before sleeping. He always placed the cup in the kitchen after he finished, and the chef or his wife usually washed the cup with other dishes.', 'S2T2C7', 'Detective', 'owner', 'habit'\n",
#  "196, '[Villager] The wife or the chef often washed the cup for the owner after he finished the milk before sleep every day.', 'S2T2C8', 'Villager', 'wash', 'cup'\n",
#  "197, '[Former Employee] The hotel has a long history of over 100 years. Also, the hotel is still very profitable because of its special hot spring. After the owner\\'s death, his brother will inherit the hotel\\'s operation.', 'S2T2C11', 'Former Employee', 'hotel', 'histoey'\n",
#  "198, '[Villager] Last day, I saw the brother sleeping on the bench in front of the hotel with a green blanket. I believe that he is drunk and lethargic. ', 'S2T2C19', 'Villager', 'brother', 'drunk'\n",
#  "199, '[Detective] The brother was drunk last night and fell asleep on a branch in front of the hotel with a green blanket.', 'S2T2C20', 'Detective', 'brother', 'blanket'\n",
#  "200, '[Villager] The brother slept on the branch outside of hotel yesterday with a green blanket. Before that he drunk with his peers.', 'S2T2C21', 'Villager', 'brother', 'blanket'\n",
#  "201, '[Former Employee] The wife has invested in many real estates recently. Some of the assets are losing their value due to the recession. The debt and interest payment is a huge burden to them.', 'S2T2C35', 'Former Employee', 'wife', 'debt'\n",
#  "202, '[Former Employee] I know little about the brother because he seldom showed up at the hotel. Also, he is a quiet person, and I never had a conversation with him.', 'S2T2C16', 'Former Employee', 'brother', 'quiet'\n",
#  "203, '[Villager] The brother left the village at a very young age. I remember that year he had a great fight with his brother (the owner) and his father. After that, he went to the city by himself.', 'S2T2C18', 'Villager', 'brother', 'fight'\n",
# ...
#  "326, 'The harmful use of alcohol is a serious social issue. Consumption of alcohol can lead to disabilities and physical and mental health problems. It also leads to 3 million deaths each year globally.', 'S3T2C39', 'Alcohol', 'consumption', 'social issue'\n",
#  "327, 'Molds can not live with high acid content. Therefore, storing food in vinegar or food containing lemon or tomatoes is not easy to be polluted by molds.', 'S3T2C40', 'vinegar', 'pollute', 'Mold'\n",
#  "328, 'Research done by JHU suggests storing washed food in the fridge is a helpful practice. By this method, bacteria and viruses in the refrigerator can be reduced.', 'S3T2C41', 'fridge', 'store', 'bacteria'\n",
#  "329, 'Some researchers suggest that daily food consumption cannot provide sufficient nutrients to the body in the modern day. For example, humans need high levels of beta-carotene, which can effectively prevent lung cancer.', 'S3T2C43', 'nutrients', 'insufficient', 'daily food'\n",
#  "330, 'Though alcohol consumption is related to some types of cancers, some research suggests that red wine can reduce the risk of heart disease and cancer.', 'S3T2C44', 'cancer', 'red wine', 'alcohol'\n",
#  "331, 'Salted fish is a suitable method for long-term storage. This can prevent the fish cause carcinogen ingredients. ', 'S3T2C42', 'storage', 'fish', 'salted'\n",
#  "332, 'Mold often grows on various crops and food and penetrates the food, not just the surface. Mold can produce mycotoxins, including Aflatoxins, Ochratoxin A, Patulin, Fusarium, etc.', 'S3T2C9', 'mold', 'produce', 'grow'\n",
#  "333, 'Common mycotoxins includes Aflatoxins, Ochratoxin A, Patulin, Fusarium, etc. Mold that produces mycotoxins can grow on various crops and food. They also can penetrate deep into food but not just on the surface.', 'S3T2C8', 'mycotoxins', 'mold', 'surface'\n",
#  "334, 'Mycotoxins are toxic compounds that are naturally produced by some types of fungi. The effect are acute symptoms of severe illness quickly after consumption, while the long-term effect includes induction of cancers and immune deficiency.', 'S3T2C7', 'toxic', 'Mycotoxins', 'fungi'\n",
#  "335, 'N-Nitrosodimethylamine is yellow, volatile, and oily liquid with no distinct odor. When heating N-Nitrosodimethylamine to decomposition, it will emits toxic fumes of nitrogen oxides.', 'S3T2C18', 'N-Nitrosodimethylamine', 'liquid', 'odor'\n",
#  "336, 'N-Nitrosodimethylamine and nitrosamines are inadvertently present in food including smoked foods, preserved meats, alcoholic beverages, and in tobacco smoke.', 'S3T2C16', 'N-Nitrosodimethylamine', 'nitrosamines', 'smoke'\n",
#  "337, 'N-Nitrosodimethylamine produces tumors in experimental animals often on liver and sometimes on bile duct, kidney, lung, and nasal cavity.', 'S3T2C17', 'tumor', 'N-Nitrosodimethylamine', 'animal'\n",
#  "338, 'Ochratoxin A can be produced by some kinds of molds. Human are possilbe exposed to it, especially from grain. Also, animal products from animals consuming contaminated feeds and grain products including beer are also possible routes.', 'S3T2C10', 'Ochratoxin A', 'expose', 'animal'\n",
#  "339, 'Some kidney diseases spread in southeastern Europe in the early 1960s, and no one knew the reason for the disease. In 1965, the reason was discovered that kidney affection is related to ochratoxin.', 'S3T2C12', 'Ochratoxin', 'kidney', 'disease x'\n",
#  "340, 'The liver and kidney are possible target organs for the carcinogenic effects of Ochratoxin A in animals. Also, nephropathy (kidney disease) affection in southeastern Europe in 1960s was found to be associated with ochratoxin.', 'S3T2C11', 'Ochratoxin A', 'kidney disease', 'liver'\n",
#  "341, 'Ochratoxin often affect dried fish, dried beans, coffee beans, seeds, wheat products, etc. These fungi produce ochratoxin adapt and contaminate in different range for optimal temperature and water activity.', 'S3T2C13', 'Ochratoxin', 'contaminate', 'fungi'\n",
#  "342, 'Natural fermentation is often used for preserving or pickling food. However, pickled food is at higher risk of being contaminated with mold with natural fermentation. Also, the food is prone to mutagens.', 'S3T2C15', 'preserve', 'fermentation', 'pickled food'\n",
#  "343, 'One method for pickling vegetables is relying on natural fermentation instead of using salt or vinegar. However, this method makes pickled vegetables more prone to mould contamination. Also, some laboratory evidence suggested that these vegetables may contain mutagens.', 'S3T2C14', 'fermentation', 'salt', 'vegetables'\n",
#  "344, 'In the 1970s, dam construction projects went on worldwide. During this period, the rise of the sea level slowed down because the dams could preserve water on land, which generally flows into the sea.', 'S3T3C9', '1970', 'dam', 'construction'\n",
#  "345, 'From the simulation performed by Dasgupta et al.(2009), the effect of different extent in sea levels rising will cause East Asia and the Middle East, and North Africa (MENA) would experience the most significant percentage of damage to population and economics.', 'S3T3C13', 'effect', 'simulation', 'population'\n",
#  "346, 'High ocean-heat content can contribute to sea-level rise. It describes the amount of heat stored in the upper levels of the ocean, which was a record high in 2021. The seven highest OHCs have occurred in the last seven years (2015-2021).', 'S3T3C14', 'heat', 'sea levels', 'cause'\n",
#  "347, 'Ice melt is one of the main reasons for rising the sea level. The ice is from ice sheets and mountain glaciers, especially in Greenland or the Antarctic.', 'S3T3C15', 'Cause', 'sea levels', 'ice melt'\n",
#  "348, 'The process of thermal expansion in water happens when water absorb the heat. As the temperature rise for the water, the water\\'s volume would expand.', 'S3T3C16', 'Cause', 'volume', 'thermal expansion'\n",
#  "349, 'Thermal expansion accounts for about 25% of the observed sea-level rise since 1960 and about 50% from 1993 to 2003. Thermal expansion is highly related to ocean temperature, and the data started to be collected in the late 20th century.', 'S3T3C20', 'thermal expansion', 'cause', 'ocean'\n",
#  "350, 'Most countries in South, Southeast and East Asia are highly threatened because of the densely populated deltas, which would be fragile to flooding due to the low elevation.', 'S3T3C35', 'impact', 'population', 'flood'\n",
#  "351, 'Satellites can help researchers to improve the measurement of the sea level. With the satellite data, the scientists found out that the traditional measurement method (based on tide-gauge) led to an overestimated result.', 'S3T3C7', 'Satellites', 'measurement', 'sea level'\n",
#  "352, 'Satellite technologies can measure sea level, which is greatly improved compared to traditional methods. With the techniques, the scientists found the conventional ways tempt to overestimate the difference in the sea levels.', 'S3T3C8', 'traditional', 'measurement', 'scientist'\n",
#  "353, 'Climate change causes more extreme weather, and rising sea levels will likely amplify the impacts of these extreme events. For example, storms and elevated sea levels can cause devastating floods.', 'S3T3C11', 'amplify', 'climate change', 'extreme weather'\n",
#  "354, 'The rising sea level is a part of climate change. It can also strengthen disasters causing more extreme weather events such as devastating floods when there is a storm.', 'S3T3C12', 'sea level', 'disaster', 'storm'\n",
#  "355, 'It is believed that carbon dioxide and other greenhouse gas emissions lead to a rise in temperature. This has resulted from human actions in using fossil fuels or oil.', 'S3T3C17', 'temperature', 'fossil fuels', 'greenhouse'\n",
#  "356, 'Deforestation is also one reason that leads to the rise in global temperature. Trees are critical players in nature in removing carbon dioxide. Cutting excessive trees will lead to abundant greenhouse gas in the atmosphere.', 'S3T3C18', 'gas', 'deforestation', 'global'\n",
#  "357, 'The ice-breaking ships make strips of open water. Open water would absorb more heat from the sun and melt away the sea ice along that trail.', 'S3T3C19', 'heat', 'water', 'ship'\n",
#  "358, 'Many studies did not consider the adaption for the impacts. However, protection would be an option to mitigate the potential impacts of sea-level rise for well-populated coastal areas.', 'S3T3C27', 'impact', 'mitigate', 'adapt'\n",
#  "359, 'Due to the rising sea level, 20 90% of existing coastal wetlands could be lost by the end of the century. These areas include farmlands, aquaculture ponds, tourist resorts, roads, harbors, etc.', 'S3T3C36', 'wetlands', 'farmland', 'pond'\n",
#  "360, 'Higher sea levels coincide with more dangerous hurricanes and typhoons. They move more slowly and drop more rain, contributing to more powerful storms.', 'S3T3C4', 'typhoons', 'hurricanes', 'sea level'\n",
#  "361, 'Because the temperature of the sea gets warmer, there will be more hurricanes and typhoons. They tempt to move slowly, drop more rain, and cause more disasters to human living.', 'S3T3C5', 'hurricanes', 'warm', 'rain'\n",
#  "362, 'Glaciers naturally melt a bit each summer, while in winter, snows from evaporated seawater should be generally sufficient to balance the melting.', 'S3T3C6', 'glaciers', 'melt', 'balance'\n",
#  "363, 'Ice can reflect at least 50 percent of the sun\\'s energy even in the melting season of summer. The ocean only reflects about 10 percent of the sun\\'s energy, and 90 percent is absorbed. The energy would warm the ocean and the atmosphere.', 'S3T3C10', 'ice', 'reflect', 'energy'\n",
#  "364, 'Sea level rise leads to the water invading coastal areas. The invasion of the water will reduce humans\\' housing areas, and it also damages animals\\' habitats.', 'S3T3C24', 'coastal', 'sea level', 'damage'\n",
#  "365, 'Sea level rise also leads to soil erosion in the coastal areas. This will lead to damage to farmland because of the abnormal level of salt in the soil.', 'S3T3C25', 'soil', 'farmland', 'salt'\n",
#  "366, 'The rise of the sea level will cause the ocean shallowed low-lying islands. This might lead to lots of land disappearing and even some countries are disappearing.', 'S3T3C26', 'ocean', 'island', 'country'\n",
#  "367, 'The immediate effect of sea-level rise is submergence, flooding of coastal land, and saltwater intrusion of surface waters.', 'S3T3C28', 'surface', 'submergence', 'coastal'\n",
#  "368, 'Longer-term effects of sea-level rise occur as the coast adjusts to the new conditions, including increased erosion and saltwater intrusion into groundwater.', 'S3T3C29', 'sea level', 'coast', 'groundwater'\n",
#  "369, 'Sea level rise leads to adjustments of coasts to the new conditions, erosion, and groundwater intruded by saltwater in the long run.', 'S3T3C30', 'salt water', 'coastal', 'sea level'\n",
#  "370, 'There are two possible sides to the policies regarding the sea level rise. First, the climate mitigation policies focused on the climate effect of human actions. Secondly, coastal management policy must consider the impact on human activities in the coastal area by the sea level rise.', 'S3T3C37', 'climate', 'solution', 'coast'\n",
#  "371, 'Climate mitigation policies include strategies to reduce carbon dioxide emissions and enhance the innovation or adoption of renewable energy.', 'S3T3C38', 'climate mitigation', 'co2', 'renewable'\n",
#  "372, 'In Netherlands and Germany, climate dikes were built to mitigate the disasters caused by sea levels rising. These dikes can protect the hinterland from flooding and prevent coastal retreat. ', 'S3T3C41', 'mitigate', 'flooding', 'climate'\n",
#  "373, 'Greenhouse gases are the gases that can trap heat in the atmosphere. For example, Carbon dioxide (CO2), Methane (CH4), Nitrous oxide (N3O), etc. are greenhouse gases. Carbon dioxide is the primary greenhouse gas emitted through human activities, which accounts for about 79% in 2020 for the U.S.', 'S3T3C21', 'heat', 'gases', 'greenhouse'\n",
#  "374, 'The main human activity that emits CO2 is by consuming fossil fuels (coal, natural gas, and oil) for energy. In the U.S., about 33% came from transportation, 31% used for electricity generating, and the other 30% came from industry and commerce in 2020.', 'S3T3C22', 'human activity', 'fosil fuel', 'transportatin'\n",
#  "375, 'Human activities that consume fossil fuels are the primary source of CO2 emission. According to the statistics, over 33% of CO2 emissions came from transportation, 31% from electricity generation, and 30% from industry and commerce.', 'S3T3C23', 'fossil fuels', 'human ', 'electricity'\n",
#  "376, 'Those coastal zones with dense populations, low elevations, or inadequate adaptive capacity (not able to adapt to extreme situation because of low biotic diversity) are at the highest risk for sea-level rise.', 'S3T3C33', 'population', 'coastal', 'elevation'\n",
#  "377, 'There are several locations at the highest risk for sea level rise especially the coastal zones with dense populations and low elevations. For example, global metropolitans, including New Orleans, New York, Bangkok, Amsterdam, London, etc., are at high risk.', 'S3T3C34', 'risk', 'sea level rise', 'global'\n",
#  "378, 'Possible methods to encourage the reduction of carbon dioxide emission include (1) emissions price, (2) emissions performance standard, (3) fossil power tax, (4) renewables share requirement, (5) renewables subsidy, and (6) R&D subsidy.', 'S3T3C39', 'reduction', 'co2', 'encourage'\n",
#  "379, 'Portfolio standards are also known as quota obligations or green certificates. It requires the producers or users of fossil energy also derive a percentage of their energy or electricity from renewable sources.', 'S3T3C40', 'portfolio standards', 'producers', 'fossil'\n",
#  "380, 'The average land and ocean temperature in 2021 was 1.51 degrees F (0.84 degrees C) above the 20th-century average. 2021 was the 6th-warmest year on record, tied with 2018.', 'S3T3C1', 'ocean', 'land', 'temperature'\n",
#  "381, 'The average annual sea ice cover in the Arctic was about 4.08 million square miles in 2021, which is the ninth-smallest annual average cover in the 1979-2021 record. In the Antarctic, the annual sea ice cover was slightly below average at 4.42 million square miles, which is the 18th smallest on record.', 'S3T3C2', 'ice', 'cover', 'sea '\n",
#  "382, 'The Greenland and Antarctic ice sheets contain enough water to raise the sea level by almost 70 m.', 'S3T3C3', 'raise', 'ice sheets', 'enough'\n",
#  "383, 'The melt of ice glaciers would cause extreme flooding. The melting water in spring or summer goes quickly and might create lakes by some blockages. When the blockages are fragile, the water in large volumes will cause an extreme flood downstream.', 'S3T3C31', 'glacier', 'flood', 'spring'\n",
#  "384, 'The melting ice glaciers can cause massive damage to human beings. For example, monsoon rains with melting glaciers in Pakistan caused floods and killed over one thousand people in 2022.', 'S3T3C32', 'melt', 'damage', 'human '\n",
#  "385, 'Sea level rising can be a false topic. There are several photos of the coastline decades ago, and there is no significant difference compared with the current coastline.', 'S3T3C42', 'sea level', 'false topic', 'difference'\n",
#  "386, 'The change in the geologic structures under the sea might also cause the sea level to rise. For example, a deep-sea earthquake could change the sea level.', 'S3T3C43', 'geologic', 'change', 'change'\n",
#  "387, 'Sea level rise can also benefit human beings. With warmer water and a more extensive range of habitats for some creatures, the fishing industry can be benefited.', 'S3T3C44', 'benefit', 'human ', 'water'\n",
#  "388, 'One of the instant way to prevent sea level rising is to prevent the floating icebergs from melting. Some research suggested that protecting the icebergs can slow down the speed of global sea level rising.', 'S3T3C45', 'icebergs', 'prevent', 'melt'"]

# %%
transform_line(lines[2])
# Out:
# "2; 'Suppose AAA tries to expand its business sector for influenza treatment in Asia. In that case, the largest medicine distributor in Asia, ME, will be a candidate with potential.'; 'S1T1C17'; 'ME'; 'expansion'; 'AAA'\n"

# %%
with open("cards_v1.csv", "w") as cards_v1_file:
  for line in lines[1:]:
    cards_v1_file.write(transform_line(line))

# %% [markdown]
# # Phase 2 Clean
#
# Separate "name" column.

# %%
import pandas as pd

# %%
df = pd.read_csv("cards_v1.csv", sep=";")
df
# Out:
#       id                                        description        name  \
# 0      1   'A long-term partner with AAA,the company ME ...   'S1T1C16'
# 1      2   'Suppose AAA tries to expand its business sec...   'S1T1C17'
# 2      3   'ME had stable growth in their sales revenue ...    'S1T1C1'
# 3      4   'AAA\'s board members maintained a good relat...   'S1T1C18'
# 4      5   'The company pleaded guilty to the false prom...   'S1T1C25'
# ..   ...                                                ...         ...
# 383  384   'The melting ice glaciers can cause massive d...   'S3T3C32'
# 384  385   'Sea level rising can be a false topic. There...   'S3T3C42'
# 385  386   'The change in the geologic structures under ...   'S3T3C43'
# 386  387   'Sea level rise can also benefit human beings...   'S3T3C44'
# 387  388   'One of the instant way to prevent sea level ...   'S3T3C45'
#
#          keyword1        keyword2            keyword3
# 0            'ME'          'Asia'         'Influenza'
# 1            'ME'     'expansion'               'AAA'
# 2            'ME'        'growth'           'revenue'
# 3            'ME'           'AAA'      'relationship'
# 4            'ME'        'guilty'   'false promotion'
# ..            ...             ...                 ...
# 383        'melt'        'damage'            'human '
# 384   'sea level'   'false topic'        'difference'
# 385    'geologic'        'change'            'change'
# 386     'benefit'        'human '             'water'
# 387    'icebergs'       'prevent'              'melt'
#
# [388 rows x 6 columns]

# %%
def parse_name_fn(name_str:str):
  ans_list = [0,0,0]
  parsing_num_flag = False
  num_i = 0
  for c_char in name_str:
    if c_char.isdigit():
      ans_list[num_i] = ans_list[num_i] * 10 + int(c_char)
      parsing_num_flag = True
    else:
      if parsing_num_flag == True:
        parsing_num_flag = False
        num_i += 1

  return (ans_list[0], ans_list[1], ans_list[2])

assert(parse_name_fn("S1T1C16") == (1,1,16))

# %%
df.columns
# Out:
# Index(['id', ' description', ' name', ' keyword1', ' keyword2', ' keyword3'], dtype='object')

# %%
COL_S_ID_NAME = "scenario_id"
COL_T_ID_NAME = "type_id"
COL_C_ID_NAME = "local_card_id"
COL_DESCRIPTION_NAME = "description"
COL_KEY_1_NAME = "keyword1"
COL_KEY_2_NAME = "keyword2"
COL_KEY_3_NAME = "keyword3"

# %%
df[COL_S_ID_NAME] = df["name"].transform(lambda x: parse_name_fn(x)[0])
df[COL_T_ID_NAME] = df["name"].transform(lambda x: parse_name_fn(x)[1])
df[COL_C_ID_NAME] = df["name"].transform(lambda x: parse_name_fn(x)[2])

# %% [markdown]
# ## Clean Description Column

# %%
DESCRITPION_TRIM_STR = ' \''
def clean_description_fn(description_str:str):
  return description_str.lstrip(DESCRITPION_TRIM_STR).rstrip(DESCRITPION_TRIM_STR)

assert(clean_description_fn("  'hello world' ") == "hello world")

# %%
for col_name in [COL_DESCRIPTION_NAME, COL_KEY_1_NAME, COL_KEY_2_NAME, COL_KEY_3_NAME]:
  df[col_name] = df[col_name].transform(clean_description_fn)
df
# Out:
#       id                                        description        name  \
# 0      1  A long-term partner with AAA,the company ME is...   'S1T1C16'
# 1      2  Suppose AAA tries to expand its business secto...   'S1T1C17'
# 2      3  ME had stable growth in their sales revenue of...    'S1T1C1'
# 3      4  AAA\'s board members maintained a good relatio...   'S1T1C18'
# 4      5  The company pleaded guilty to the false promot...   'S1T1C25'
# ..   ...                                                ...         ...
# 383  384  The melting ice glaciers can cause massive dam...   'S3T3C32'
# 384  385  Sea level rising can be a false topic. There a...   'S3T3C42'
# 385  386  The change in the geologic structures under th...   'S3T3C43'
# 386  387  Sea level rise can also benefit human beings. ...   'S3T3C44'
# 387  388  One of the instant way to prevent sea level ri...   'S3T3C45'
#
#       keyword1     keyword2         keyword3  scenario_id  turn_id  \
# 0           ME         Asia        Influenza            1        1
# 1           ME    expansion              AAA            1        1
# 2           ME       growth          revenue            1        1
# 3           ME          AAA     relationship            1        1
# 4           ME       guilty  false promotion            1        1
# ..         ...          ...              ...          ...      ...
# 383       melt       damage            human            3        3
# 384  sea level  false topic       difference            3        3
# 385   geologic       change           change            3        3
# 386    benefit        human            water            3        3
# 387   icebergs      prevent             melt            3        3
#
#      local_card_id  type_id
# 0               16        1
# 1               17        1
# 2                1        1
# 3               18        1
# 4               25        1
# ..             ...      ...
# 383             32        3
# 384             42        3
# 385             43        3
# 386             44        3
# 387             45        3
#
# [388 rows x 10 columns]

# %%
FINAL_COL_NAME_LIST = [COL_S_ID_NAME, COL_T_ID_NAME, COL_C_ID_NAME, COL_KEY_1_NAME, COL_KEY_2_NAME, COL_KEY_3_NAME, COL_DESCRIPTION_NAME]

# %%
df_1 = df[FINAL_COL_NAME_LIST]

# %%
df_1
# Out:
#      scenario_id  type_id  local_card_id   keyword1     keyword2  \
# 0              1        1             16         ME         Asia
# 1              1        1             17         ME    expansion
# 2              1        1              1         ME       growth
# 3              1        1             18         ME          AAA
# 4              1        1             25         ME       guilty
# ..           ...      ...            ...        ...          ...
# 383            3        3             32       melt       damage
# 384            3        3             42  sea level  false topic
# 385            3        3             43   geologic       change
# 386            3        3             44    benefit        human
# 387            3        3             45   icebergs      prevent
#
#             keyword3                                        description
# 0          Influenza  A long-term partner with AAA,the company ME is...
# 1                AAA  Suppose AAA tries to expand its business secto...
# 2            revenue  ME had stable growth in their sales revenue of...
# 3       relationship  AAA\'s board members maintained a good relatio...
# 4    false promotion  The company pleaded guilty to the false promot...
# ..               ...                                                ...
# 383            human  The melting ice glaciers can cause massive dam...
# 384       difference  Sea level rising can be a false topic. There a...
# 385           change  The change in the geologic structures under th...
# 386            water  Sea level rise can also benefit human beings. ...
# 387             melt  One of the instant way to prevent sea level ri...
#
# [388 rows x 7 columns]

# %% [markdown]
# ## Prepare to Save

# %%
df_final = df_1.sort_values(axis=0, by=[COL_S_ID_NAME, COL_T_ID_NAME, COL_C_ID_NAME]).reset_index()[FINAL_COL_NAME_LIST]
df_final
# Out:
#      scenario_id  type_id  local_card_id   keyword1      keyword2  \
# 0              1        1              1         ME        growth
# 1              1        1              2         ME      lobbying
# 2              1        1              3         NJ       vaccine
# 3              1        1              4         NJ        patent
# 4              1        1              5         NJ  partnerships
# ..           ...      ...            ...        ...           ...
# 383            3        3             41   mitigate      flooding
# 384            3        3             42  sea level   false topic
# 385            3        3             43   geologic        change
# 386            3        3             44    benefit         human
# 387            3        3             45   icebergs       prevent
#
#           keyword3                                        description
# 0          revenue  ME had stable growth in their sales revenue of...
# 1     expenditures  To maintain the advantage in bargaining with g...
# 2    effectiveness  The company is developing a new generation vac...
# 3        influenza  NJ owns research centers in East Asia and part...
# 4        factories  NJ partners with local manufacturers and owns ...
# ..             ...                                                ...
# 383        climate  In Netherlands and Germany, climate dikes were...
# 384     difference  Sea level rising can be a false topic. There a...
# 385         change  The change in the geologic structures under th...
# 386          water  Sea level rise can also benefit human beings. ...
# 387           melt  One of the instant way to prevent sea level ri...
#
# [388 rows x 7 columns]

# %%
df_final.to_csv("cards.csv", quoting=2, quotechar='"')
